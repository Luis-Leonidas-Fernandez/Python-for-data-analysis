# %% [markdown]
# # MovieLens Analysis Project
#
#
# ## Project checklist
#
# 1. Define the question.
# 2. Load the dataset.
# 3. Inspect structure and missing values.
# 4. Clean and transform data.
# 5. Create visual analysis.
# 6. Write conclusions.
# 7. List next improvements.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[1] if Path.cwd().name in {'notebooks', 'projects'} else Path.cwd()
DATASETS_DIR = PROJECT_ROOT / 'datasets'
EXAMPLES_DIR = PROJECT_ROOT / 'examples'

PROJECT_ROOT, DATASETS_DIR, EXAMPLES_DIR

# %%
import numpy as np
import pandas as pd

pd.__version__
