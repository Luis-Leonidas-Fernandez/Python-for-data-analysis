# %% [markdown]
# # Chapter 06 — Practice Notebook
#
# This notebook is my guided practice space for `ch06.ipynb`.
#
# ## How to use this notebook
#
# For each example:
#
# 1. Read the original code.
# 2. Rewrite it in the `My version` cell using different values.
# 3. Run your version.
# 4. Explain what happened in `What I learned`.
#
# The goal is not to copy code. The goal is to understand the concept and explain it clearly.
#
# Original reference notebook: `../../_original/ch06.ipynb`

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[1] if Path.cwd().name in {'notebooks', 'projects'} else Path.cwd()
DATASETS_DIR = PROJECT_ROOT / 'datasets'
EXAMPLES_DIR = PROJECT_ROOT / 'examples'
OUTPUTS_DIR = PROJECT_ROOT / 'book' / 'outputs'
OUTPUTS_DIR.mkdir(parents=True, exist_ok=True)

PROJECT_ROOT, DATASETS_DIR, EXAMPLES_DIR, OUTPUTS_DIR

# %% [markdown]
# ## Example 01
#
# ### Original code
#
# ```python
# import numpy as np
# import pandas as pd
# np.random.seed(12345)
# import matplotlib.pyplot as plt
# plt.rc("figure", figsize=(10, 6))
# pd.options.display.max_colwidth = 75
# pd.options.display.max_columns = 20
# np.set_printoptions(precision=4, suppress=True)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 02
#
# ### Original code
#
# ```python
# !cat examples/ex1.csv
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 03
#
# ### Original code
#
# ```python
# df = pd.read_csv("examples/ex1.csv")
# df
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 04
#
# ### Original code
#
# ```python
# !cat examples/ex2.csv
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 05
#
# ### Original code
#
# ```python
# pd.read_csv("examples/ex2.csv", header=None)
# pd.read_csv("examples/ex2.csv", names=["a", "b", "c", "d", "message"])
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 06
#
# ### Original code
#
# ```python
# names = ["a", "b", "c", "d", "message"]
# pd.read_csv("examples/ex2.csv", names=names, index_col="message")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 07
#
# ### Original code
#
# ```python
# !cat examples/csv_mindex.csv
# parsed = pd.read_csv("examples/csv_mindex.csv",
#                      index_col=["key1", "key2"])
# parsed
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 08
#
# ### Original code
#
# ```python
# !cat examples/ex3.txt
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 09
#
# ### Original code
#
# ```python
# result = pd.read_csv("examples/ex3.txt", sep="\s+")
# result
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 10
#
# ### Original code
#
# ```python
# !cat examples/ex4.csv
# pd.read_csv("examples/ex4.csv", skiprows=[0, 2, 3])
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 11
#
# ### Original code
#
# ```python
# !cat examples/ex5.csv
# result = pd.read_csv("examples/ex5.csv")
# result
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 12
#
# ### Original code
#
# ```python
# pd.isna(result)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 13
#
# ### Original code
#
# ```python
# result = pd.read_csv("examples/ex5.csv", na_values=["NULL"])
# result
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 14
#
# ### Original code
#
# ```python
# result2 = pd.read_csv("examples/ex5.csv", keep_default_na=False)
# result2
# result2.isna()
# result3 = pd.read_csv("examples/ex5.csv", keep_default_na=False,
#                       na_values=["NA"])
# result3
# result3.isna()
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 15
#
# ### Original code
#
# ```python
# sentinels = {"message": ["foo", "NA"], "something": ["two"]}
# pd.read_csv("examples/ex5.csv", na_values=sentinels,
#             keep_default_na=False)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 16
#
# ### Original code
#
# ```python
# pd.options.display.max_rows = 10
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 17
#
# ### Original code
#
# ```python
# result = pd.read_csv("examples/ex6.csv")
# result
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 18
#
# ### Original code
#
# ```python
# pd.read_csv("examples/ex6.csv", nrows=5)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 19
#
# ### Original code
#
# ```python
# chunker = pd.read_csv("examples/ex6.csv", chunksize=1000)
# type(chunker)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 20
#
# ### Original code
#
# ```python
# chunker = pd.read_csv("examples/ex6.csv", chunksize=1000)
#
# tot = pd.Series([], dtype='int64')
# for piece in chunker:
#     tot = tot.add(piece["key"].value_counts(), fill_value=0)
#
# tot = tot.sort_values(ascending=False)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 21
#
# ### Original code
#
# ```python
# tot[:10]
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 22
#
# ### Original code
#
# ```python
# data = pd.read_csv("examples/ex5.csv")
# data
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 23
#
# ### Original code
#
# ```python
# data.to_csv(OUTPUTS_DIR / "out.csv")
# !cat {OUTPUTS_DIR / "out.csv"}
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.
#
#
# > Practice note: generated files should go in `OUTPUTS_DIR` (`book/outputs/`) so `examples/` and `datasets/` stay clean.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 24
#
# ### Original code
#
# ```python
# import sys
# data.to_csv(sys.stdout, sep="|")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 25
#
# ### Original code
#
# ```python
# data.to_csv(sys.stdout, na_rep="NULL")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 26
#
# ### Original code
#
# ```python
# data.to_csv(sys.stdout, index=False, header=False)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 27
#
# ### Original code
#
# ```python
# data.to_csv(sys.stdout, index=False, columns=["a", "b", "c"])
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 28
#
# ### Original code
#
# ```python
# !cat examples/ex7.csv
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 29
#
# ### Original code
#
# ```python
# import csv
# f = open("examples/ex7.csv")
# reader = csv.reader(f)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 30
#
# ### Original code
#
# ```python
# for line in reader:
#     print(line)
# f.close()
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 31
#
# ### Original code
#
# ```python
# with open("examples/ex7.csv") as f:
#     lines = list(csv.reader(f))
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 32
#
# ### Original code
#
# ```python
# header, values = lines[0], lines[1:]
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 33
#
# ### Original code
#
# ```python
# data_dict = {h: v for h, v in zip(header, zip(*values))}
# data_dict
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 34
#
# ### Original code
#
# ```python
# obj = """
# {"name": "Wes",
#  "cities_lived": ["Akron", "Nashville", "New York", "San Francisco"],
#  "pet": null,
#  "siblings": [{"name": "Scott", "age": 34, "hobbies": ["guitars", "soccer"]},
#               {"name": "Katie", "age": 42, "hobbies": ["diving", "art"]}]
# }
# """
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 35
#
# ### Original code
#
# ```python
# import json
# result = json.loads(obj)
# result
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 36
#
# ### Original code
#
# ```python
# asjson = json.dumps(result)
# asjson
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 37
#
# ### Original code
#
# ```python
# siblings = pd.DataFrame(result["siblings"], columns=["name", "age"])
# siblings
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 38
#
# ### Original code
#
# ```python
# !cat examples/example.json
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 39
#
# ### Original code
#
# ```python
# data = pd.read_json("examples/example.json")
# data
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 40
#
# ### Original code
#
# ```python
# data.to_json(sys.stdout)
# data.to_json(sys.stdout, orient="records")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 41
#
# ### Original code
#
# ```python
# tables = pd.read_html("examples/fdic_failed_bank_list.html")
# len(tables)
# failures = tables[0]
# failures.head()
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 42
#
# ### Original code
#
# ```python
# close_timestamps = pd.to_datetime(failures["Closing Date"])
# close_timestamps.dt.year.value_counts()
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 43
#
# ### Original code
#
# ```python
# from lxml import objectify
#
# path = "datasets/mta_perf/Performance_MNR.xml"
# with open(path) as f:
#     parsed = objectify.parse(f)
# root = parsed.getroot()
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 44
#
# ### Original code
#
# ```python
# data = []
#
# skip_fields = ["PARENT_SEQ", "INDICATOR_SEQ",
#                "DESIRED_CHANGE", "DECIMAL_PLACES"]
#
# for elt in root.INDICATOR:
#     el_data = {}
#     for child in elt.getchildren():
#         if child.tag in skip_fields:
#             continue
#         el_data[child.tag] = child.pyval
#     data.append(el_data)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 45
#
# ### Original code
#
# ```python
# perf = pd.DataFrame(data)
# perf.head()
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 46
#
# ### Original code
#
# ```python
# perf2 = pd.read_xml(path)
# perf2.head()
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 47
#
# ### Original code
#
# ```python
# frame = pd.read_csv("examples/ex1.csv")
# frame
# frame.to_pickle(OUTPUTS_DIR / "frame_pickle")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.
#
#
# > Practice note: generated files should go in `OUTPUTS_DIR` (`book/outputs/`) so `examples/` and `datasets/` stay clean.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 48
#
# ### Original code
#
# ```python
# pd.read_pickle("examples/frame_pickle")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 49
#
# ### Original code
#
# ```python
# !rm examples/frame_pickle
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 50
#
# ### Original code
#
# ```python
# fec = pd.read_parquet('datasets/fec/fec.parquet')
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 51
#
# ### Original code
#
# ```python
# xlsx = pd.ExcelFile("examples/ex1.xlsx")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 52
#
# ### Original code
#
# ```python
# xlsx.sheet_names
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 53
#
# ### Original code
#
# ```python
# xlsx.parse(sheet_name="Sheet1")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 54
#
# ### Original code
#
# ```python
# xlsx.parse(sheet_name="Sheet1", index_col=0)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 55
#
# ### Original code
#
# ```python
# frame = pd.read_excel("examples/ex1.xlsx", sheet_name="Sheet1")
# frame
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 56
#
# ### Original code
#
# ```python
# writer = pd.ExcelWriter(OUTPUTS_DIR / "ex2.xlsx")
# frame.to_excel(writer, "Sheet1")
# writer.close()
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.
#
#
# > Practice note: generated files should go in `OUTPUTS_DIR` (`book/outputs/`) so `examples/` and `datasets/` stay clean.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 57
#
# ### Original code
#
# ```python
# frame.to_excel(OUTPUTS_DIR / "ex2.xlsx")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.
#
#
# > Practice note: generated files should go in `OUTPUTS_DIR` (`book/outputs/`) so `examples/` and `datasets/` stay clean.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 58
#
# ### Original code
#
# ```python
# !rm examples/ex2.xlsx
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 59
#
# ### Original code
#
# ```python
# !rm -f examples/mydata.h5
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 60
#
# ### Original code
#
# ```python
# frame = pd.DataFrame({"a": np.random.standard_normal(100)})
# store = pd.HDFStore(OUTPUTS_DIR / "mydata.h5")
# store["obj1"] = frame
# store["obj1_col"] = frame["a"]
# store
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.
#
#
# > Practice note: generated files should go in `OUTPUTS_DIR` (`book/outputs/`) so `examples/` and `datasets/` stay clean.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 61
#
# ### Original code
#
# ```python
# store["obj1"]
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 62
#
# ### Original code
#
# ```python
# store.put("obj2", frame, format="table")
# store.select("obj2", where=["index >= 10 and index <= 15"])
# store.close()
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 63
#
# ### Original code
#
# ```python
# frame.to_hdf(OUTPUTS_DIR / "mydata.h5", "obj3", format="table")
# pd.read_hdf(OUTPUTS_DIR / "mydata.h5", "obj3", where=["index < 5"])
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.
#
#
# > Practice note: generated files should go in `OUTPUTS_DIR` (`book/outputs/`) so `examples/` and `datasets/` stay clean.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 64
#
# ### Original code
#
# ```python
# import os
# os.remove("examples/mydata.h5")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 65
#
# ### Original code
#
# ```python
# import requests
# url = "https://api.github.com/repos/pandas-dev/pandas/issues"
# resp = requests.get(url)
# resp.raise_for_status()
# resp
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 66
#
# ### Original code
#
# ```python
# data = resp.json()
# data[0]["title"]
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 67
#
# ### Original code
#
# ```python
# issues = pd.DataFrame(data, columns=["number", "title",
#                                      "labels", "state"])
# issues
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 68
#
# ### Original code
#
# ```python
# import sqlite3
#
# query = """
# CREATE TABLE test
# (a VARCHAR(20), b VARCHAR(20),
#  c REAL,        d INTEGER
# );"""
#
# con = sqlite3.connect("mydata.sqlite")
# con.execute(query)
# con.commit()
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 69
#
# ### Original code
#
# ```python
# data = [("Atlanta", "Georgia", 1.25, 6),
#         ("Tallahassee", "Florida", 2.6, 3),
#         ("Sacramento", "California", 1.7, 5)]
# stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"
#
# con.executemany(stmt, data)
# con.commit()
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 70
#
# ### Original code
#
# ```python
# cursor = con.execute("SELECT * FROM test")
# rows = cursor.fetchall()
# rows
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 71
#
# ### Original code
#
# ```python
# cursor.description
# pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 72
#
# ### Original code
#
# ```python
# import sqlalchemy as sqla
# db = sqla.create_engine("sqlite:///mydata.sqlite")
# pd.read_sql("SELECT * FROM test", db)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 73
#
# ### Original code
#
# ```python
# !rm mydata.sqlite
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -
