# %% [markdown]
# # Chapter 08 — Data Wrangling, Join, Combine, and Reshape
#
# Original reference notebook: `../../ch08.ipynb`.
#
# ## Study checklist
#
# 1. Read the chapter section.
# 2. Rebuild the example in your own words.
# 3. Modify the data or parameters.
# 4. Break something intentionally and explain the error.
# 5. Write a short conclusion.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[1] if Path.cwd().name in {'notebooks', 'projects'} else Path.cwd()
DATASETS_DIR = PROJECT_ROOT / 'datasets'
EXAMPLES_DIR = PROJECT_ROOT / 'examples'

PROJECT_ROOT, DATASETS_DIR, EXAMPLES_DIR

# %%
import numpy as np
import pandas as pd

pd.__version__
