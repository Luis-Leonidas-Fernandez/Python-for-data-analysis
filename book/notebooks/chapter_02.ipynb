# %% [markdown]
# # Chapter 02 — Practice Notebook
#
# This notebook is my guided practice space for Chapter 02.
#
# ## How to use this notebook
#
# For each example:
#
# 1. Read the original code.
# 2. Rewrite it in the `My version` cell using different values.
# 3. Run your version.
# 4. Explain what happened in `What I learned`.
#
# The goal is not to copy code. The goal is to understand the concept and explain it clearly.
#
# Original reference notebook: `../../_original/ch02.ipynb`

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[1] if Path.cwd().name in {'notebooks', 'projects'} else Path.cwd()
DATASETS_DIR = PROJECT_ROOT / 'datasets'
EXAMPLES_DIR = PROJECT_ROOT / 'examples'
OUTPUTS_DIR = PROJECT_ROOT / 'book' / 'outputs'
OUTPUTS_DIR.mkdir(parents=True, exist_ok=True)

PROJECT_ROOT, DATASETS_DIR, EXAMPLES_DIR, OUTPUTS_DIR

# %% [markdown]
# ## Example 01
#
# ### Original code
#
# ```python
# import numpy as np
#
# np.random.seed(12345)
# np.set_printoptions(precision=4, suppress=True)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 02
#
# ### Original code
#
# ```python
# import numpy as np
#
# data = [np.random.standard_normal() for i in range(7)]
# data
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 03
#
# ### Original code
#
# ```python
# a = [1, 2, 3]
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 04
#
# ### Original code
#
# ```python
# b = a
# b
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 05
#
# ### Original code
#
# ```python
# a.append(4)
# b
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 06
#
# ### Original code
#
# ```python
# def append_element(some_list, element):
#     some_list.append(element)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 07
#
# ### Original code
#
# ```python
# data = [1, 2, 3]
# append_element(data, 4)
# data
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 08
#
# ### Original code
#
# ```python
# a = 5
# type(a)
# a = "foo"
# type(a)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 09
#
# ### Original code
#
# ```python
# "5" + 5
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 10
#
# ### Original code
#
# ```python
# a = 4.5
# b = 2
# # String formatting, to be visited later
# print(f"a is {type(a)}, b is {type(b)}")
# a / b
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 11
#
# ### Original code
#
# ```python
# a = 5
# isinstance(a, int)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 12
#
# ### Original code
#
# ```python
# a = 5; b = 4.5
# isinstance(a, (int, float))
# isinstance(b, (int, float))
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 13
#
# ### Original code
#
# ```python
# a = "foo"
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 14
#
# ### Original code
#
# ```python
# a.split
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 15
#
# ### Original code
#
# ```python
# def isiterable(obj):
#     try:
#         iter(obj)
#         return True
#     except TypeError: # not iterable
#         return False
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 16
#
# ### Original code
#
# ```python
# isiterable("a string")
# isiterable([1, 2, 3])
# isiterable(5)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 17
#
# ### Original code
#
# ```python
# 5 - 7  # noqa: B018
# 12 + 21.5  # noqa: B018
# 5 <= 2  # noqa: PLR0133
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 18
#
# ### Original code
#
# ```python
# a = [1, 2, 3]
# b = a
# c = list(a)
# a is b  # noqa: B015
# a is not c
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 19
#
# ### Original code
#
# ```python
# a == c
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 20
#
# ### Original code
#
# ```python
# a = None
# a is None
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 21
#
# ### Original code
#
# ```python
# a_list = ["foo", 2, [4, 5]]
# a_list[2] = (3, 4)
# a_list
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 22
#
# ### Original code
#
# ```python
# a_tuple = (3, 5, (4, 5))
# a_tuple[1] = "four"
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 23
#
# ### Original code
#
# ```python
# ival = 17239871
# ival ** 6
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 24
#
# ### Original code
#
# ```python
# fval = 7.243
# fval2 = 6.78e-5
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 25
#
# ### Original code
#
# ```python
# 3 / 2
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 26
#
# ### Original code
#
# ```python
# 3 // 2
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 27
#
# ### Original code
#
# ```python
# c = """
# This is a longer string that
# spans multiple lines
# """
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 28
#
# ### Original code
#
# ```python
# c.count("\n")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 29
#
# ### Original code
#
# ```python
# a = "this is a string"
# a[10] = "f"
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 30
#
# ### Original code
#
# ```python
# b = a.replace("string", "longer string")
# b
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 31
#
# ### Original code
#
# ```python
# a
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 32
#
# ### Original code
#
# ```python
# a = 5.6
# s = str(a)
# print(s)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 33
#
# ### Original code
#
# ```python
# s = "python"
# list(s)
# s[:3]
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 34
#
# ### Original code
#
# ```python
# s = "12\\34"
# print(s)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 35
#
# ### Original code
#
# ```python
# s = r"this\has\no\special\characters"
# s
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 36
#
# ### Original code
#
# ```python
# a = "this is the first half "
# b = "and this is the second half"
# a + b
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 37
#
# ### Original code
#
# ```python
# template = "{0:.2f} {1:s} are worth US${2:d}"
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 38
#
# ### Original code
#
# ```python
# template.format(88.46, "Argentine Pesos", 1)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 39
#
# ### Original code
#
# ```python
# amount = 10
# rate = 88.46
# currency = "Pesos"
# result = f"{amount} {currency} is worth US${amount / rate}"
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 40
#
# ### Original code
#
# ```python
# f"{amount} {currency} is worth US${amount / rate:.2f}"
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 41
#
# ### Original code
#
# ```python
# val = "español"
# val
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 42
#
# ### Original code
#
# ```python
# val_utf8 = val.encode("utf-8")
# val_utf8  # noqa: B018
# type(val_utf8)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 43
#
# ### Original code
#
# ```python
# val_utf8.decode("utf-8")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 44
#
# ### Original code
#
# ```python
# val.encode("latin1")
# val.encode("utf-16")
# val.encode("utf-16le")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 45
#
# ### Original code
#
# ```python
# True and True  # noqa: B018
# False or True  # noqa: SIM222
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 46
#
# ### Original code
#
# ```python
# int(False)
# int(True)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 47
#
# ### Original code
#
# ```python
# a = True
# b = False
# not a  # noqa: B018
# not b
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 48
#
# ### Original code
#
# ```python
# s = "3.14159"
# fval = float(s)
# type(fval)
# int(fval)
# bool(fval)
# bool(0)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 49
#
# ### Original code
#
# ```python
# a = None
# a is None  # noqa: B015
# b = 5
# b is not None
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 50
#
# ### Original code
#
# ```python
# from datetime import date, datetime, time  # noqa: F401
#
# dt = datetime(2011, 10, 29, 20, 30, 21)  # noqa: DTZ001
# dt.day  # noqa: B018
# dt.minute
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 51
#
# ### Original code
#
# ```python
# dt.date()
# dt.time()
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 52
#
# ### Original code
#
# ```python
# dt.strftime("%Y-%m-%d %H:%M")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 53
#
# ### Original code
#
# ```python
# datetime.strptime("20091031", "%Y%m%d")  # noqa: DTZ007
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 54
#
# ### Original code
#
# ```python
# dt_hour = dt.replace(minute=0, second=0)
# dt_hour
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 55
#
# ### Original code
#
# ```python
# dt
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 56
#
# ### Original code
#
# ```python
# dt2 = datetime(2011, 11, 15, 22, 30)  # noqa: DTZ001
# delta = dt2 - dt
# delta  # noqa: B018
# type(delta)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 57
#
# ### Original code
#
# ```python
# dt  # noqa: B018
# dt + delta
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 58
#
# ### Original code
#
# ```python
# a = 5; b = 7
# c = 8; d = 4
# if a < b or c > d:
#     print("Made it")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 59
#
# ### Original code
#
# ```python
# 4 > 3 > 2 > 1  # noqa: PLR0133
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 60
#
# ### Original code
#
# ```python
# for i in range(4):
#     for j in range(4):
#         if j > i:
#             break
#         print((i, j))
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 61
#
# ### Original code
#
# ```python
# range(10)
# list(range(10))
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 62
#
# ### Original code
#
# ```python
# list(range(0, 20, 2))
# list(range(5, 0, -1))
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 63
#
# ### Original code
#
# ```python
# seq = [1, 2, 3, 4]
# for i in range(len(seq)):
#     print(f"element {i}: {seq[i]}")
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -

# %% [markdown]
# ## Example 64
#
# ### Original code
#
# ```python
# total = 0
# for i in range(100_000):
#     # % is the modulo operator
#     if i % 3 == 0 or i % 5 == 0:
#         total += i
# print(total)
# ```
#
# ### What this example is about
#
# Write the main idea here before running your own version.

# %%
# My version
# Rewrite the example here using your own values.

# %% [markdown]
# ### What I learned
#
# -
